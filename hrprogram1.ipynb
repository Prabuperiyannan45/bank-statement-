# %%
acc_pin_number = 1234
acc_holder_name = "aaa"
acc_balance = 20000
a=int(input("Enter your pin : "))
if a==acc_pin_number:
    print("correct pin")
    def deposit(amount):
        global acc_balance
        acc_balance += amount
    def withdraw(amount):
        global acc_balance
        acc_balance -= amount
    def check_balance():
        print(acc_balance)
        return acc_balance
    deposit(10000)
    check_balance()
else:
    print("wrong pin")
# Out:
# Enter your pin : 1234
# correct pin
# 30000
